# %% [markdown]
# # Reconstruction of volume from simulated data

# %%
# %load_ext autoreload
# %autoreload 2
import site
import sys
import time
site.addsitedir('..')
from jax.config import config

config.update("jax_enable_x64", True)

# %%
import numpy as np
import jax.numpy as jnp
from matplotlib import pyplot as plt
import jax
from jax import random
from simplecryoem.utils import *
from simplecryoem.projection import *
from simplecryoem.interpolate import *
from simplecryoem.jaxops import *
from simplecryoem.fsc import *
from simplecryoem.algorithm import *
from simplecryoem.ab_initio import ab_initio, ab_initio_mcmc
from simplecryoem.residual import get_volume_residual

from pyem import star

plt.rcParams["figure.figsize"]=8,8

# %% [markdown]
# ### Generate the volume

# %%
nx = 32
shape = np.array([nx,nx,nx])
dimensions = np.array([20,20,20])
pixel_size = dimensions[0]/shape[0]

# A volume with components
centres = np.array([[0,0,0], [3, 3, 0], [3, -3, 0], [0,0,3]])
radii = np.array([3, 1.5, 1.5, 1.5])
intensities = np.array([10,15,20, 20])

vol = jnp.array(volume_comp(shape, dimensions, centres, radii, intensities, False))
vol_fourier, x_grid, _ = volume_fourier(vol, pixel_size)

y_grid = x_grid
z_grid = x_grid

mip_z(vol)
#plt.imshow(v[:,:,int(np.floor(v.shape[2]/2))])
plt.colorbar()
plt.title('Volume_comp MIP')
# Out:
# Text(0.5, 1.0, 'Volume_comp MIP')

# %%
mip_y(vol)

# %%
mip_z(jnp.fft.fftshift(jnp.abs((vol_fourier)))); plt.colorbar()

# %% [markdown]
# ### Generate the data

# %% [markdown]
# CTF

# %%
df = star.parse_star("../tests/comparison_notebooks/data/pyem.star", keep_index = False)
dfiter = df.iterrows()
_, p = next(dfiter)

#ctf_params = {'def1'  : p[star.Relion.DEFOCUSU], 
#              'def2'  : p[star.Relion.DEFOCUSV],
#              'angast': p[star.Relion.DEFOCUSANGLE], 
#              'phase' : p[star.Relion.PHASESHIFT],
#              'kv'    : p[star.Relion.VOLTAGE],
#              'ac'    : p[star.Relion.AC], 
#              'cs'    : p[star.Relion.CS], 
#              'bf'    : 0,
#              'lp'    : 2 * pixel_size}

ctf_params0 = np.array([p[star.Relion.DEFOCUSU],
                      p[star.Relion.DEFOCUSV],
                      p[star.Relion.DEFOCUSANGLE], 
                      p[star.Relion.PHASESHIFT],
                      p[star.Relion.VOLTAGE],
                      p[star.Relion.AC],
                      p[star.Relion.CS],
                      0,
                      2 * pixel_size])
# Out:
# /home/bt387/project/2021_CryoEMSolver7/external/pyem/pyem/star.py:531: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df[UCSF.IMAGE_INDEX], df[UCSF.IMAGE_PATH] = \
# /home/bt387/project/2021_CryoEMSolver7/external/pyem/pyem/star.py:539: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   df[UCSF.IMAGE_ORIGINAL_INDEX], df[UCSF.IMAGE_ORIGINAL_PATH] = \

# %%
radius = 0.8
mask = create_3d_mask(x_grid, (0,0,0),radius)
#mip_z(jnp.fft.fftshift(mask)); plt.colorbar()

slice_func,slice_func_array, slice_func_array_angles = get_slice_funcs(project, x_grid, mask, "nn")
s = 17
img = slice_func(0.1*vol_fourier, [0,0,0], [0,0], None)
img_r = jnp.fft.fftshift(jnp.real(jnp.fft.ifft2((img.reshape([nx,nx]))))) 
plt.imshow(img_r); plt.colorbar()

# %%
img_f0 = jnp.fft.fftshift(img.reshape([nx,nx]))
plt.imshow(jnp.abs(img_f0));plt.colorbar()

# %% [markdown]
# Generate projections (in Fourier domain)

# %%
# Orientations
N = 5000

#s = 0.05
s = 0.1
angles_true = generate_uniform_orientations(N)
#jnp.array(np.random.rand(N,3))*jnp.pi*2

#angles_true = jnp.array(np.random.rand(N,3))*jnp.pi/4 + jnp.pi

# Non uniformly distributed orientations (here, two clusters)
#angles_true = s*np.random.randn(int(N),3)
#angles_true = np.concatenate([s*np.random.randn(2250,3), 
#                             s*np.random.randn(2250,3)+np.pi*2/3, 
#                              np.random.rand(500,3)*jnp.pi*2
#                             ], axis=0)
#np.random.shuffle(angles_true)
#angles_true = jnp.array(angles_true)

#angles_true = np.zeros([N,3])
#angles_true[:,1] = s*np.random.randn(N) - np.pi/2
#angles_true = jnp.array(angles_true)

plot_angles(angles_true[:500])

# %%
from src.utils import *

# %%
# Shifts
key = random.PRNGKey(int(jnp.floor(np.random.rand()*1000)))
key, subkey = random.split(key)
#shifts_true = generate_uniform_shifts(key, N, pixel_size*nx/2)
shifts_true = generate_gaussian_shifts(key, N, pixel_size*nx/10)

#shifts_true = jnp.zeros([N,3])

plt.scatter(shifts_true[:,0], shifts_true[:,1])

# %%
radius = 0.8
mask = create_3d_mask(x_grid, (0,0,0),radius)
#mip_z(jnp.fft.fftshift(mask)); plt.colorbar()

slice_func,slice_func_array, slice_func_array_angles = get_slice_funcs(project, x_grid, mask, "nn")

img0 = slice_func(vol_fourier, [0,0,0], [0,0], ctf_params0)


ctf_params = jnp.array([ctf_params0] * N)
start = time.time()
imgs = slice_func_array(vol_fourier, angles_true, shifts_true, ctf_params)

# If too many images which don't fit in the gpu memory, do this:
#imgs = jnp.array([slice_func(vol_fourier, angles_true[i], shifts_true[i], ctf_params0) for i in range(N)])

norm0sq = jnp.real(jnp.sum(jnp.conj(imgs)*imgs))

# Noise
sigma = 0.2 * jnp.max(jnp.abs(img0))
imgs += (np.random.randn(N, nx*nx) + 1j*np.random.randn(N, nx*nx)) * sigma

norm1sq = jnp.real(jnp.sum(jnp.conj(imgs)*imgs))

#print(time.time()-start)

#SNR
print("SNR =", norm0sq/norm1sq)
print("sigma =", sigma)

plt.imshow(jnp.fft.fftshift(jnp.real(imgs[101].reshape(nx,nx)))); plt.colorbar()
# Out:
# SNR = 0.14308783830274405
# sigma = 37.84951113740297

# %% [markdown]
# ### Crop images and volume:

# %%
old_nx = jnp.sqrt(imgs.shape[1]).astype(jnp.int64)
nx = 32

if old_nx > 32:
    imgs = imgs.reshape(imgs.shape[0], old_nx, old_nx)
    imgs, x_grid = crop_fourier_images(imgs, x_grid, nx)
    imgs = imgs.reshape(imgs.shape[0], nx*nx)
    #imgs2 = imgs2.reshape(imgs2.shape[0], nx*nx)

    vol_fourier, _ = crop_fourier_volume(vol_fourier, x_grid, nx)

    y_grid = x_grid
    z_grid = x_grid

# %%
plt.imshow(jnp.fft.fftshift(jnp.real(imgs[103].reshape(nx,nx)))); plt.colorbar()

# %%
#mip_z(jnp.fft.fftshift(jnp.abs((vol_fourier)))); plt.colorbar()
plt.imshow(jnp.fft.fftshift(jnp.abs((vol_fourier[:,:,0])))); plt.colorbar()

# %%
#mip_z(jnp.fft.fftshift(jnp.real(jnp.fft.ifftn(vol_fourier)))); plt.colorbar()
plt.imshow(jnp.fft.fftshift(jnp.real(jnp.fft.ifftn(vol_fourier[:,:,0])))); plt.colorbar()

# %% [markdown]
# ### Loss functions for the new dimension

# %%
alpha = 0.01
#alpha = 1/N

#radius = 0.4 # for nx=16
radius = 0.75 # for nx=32
#radius = 1.6 # for nx=64
#radius = 3.2 # for nx=128
mask = create_3d_mask(x_grid, (0,0,0),radius)
mip_z(jnp.fft.fftshift(mask)); plt.colorbar()

slice_func,slice_func_array, slice_func_array_angles = get_slice_funcs(project, x_grid, mask, "tri")

loss_func, loss_func_batched, loss_func_sum, _ = get_loss_funcs(slice_func, alpha = alpha)
grad_loss_volume, grad_loss_volume_sum = get_grad_v_funcs(loss_func, loss_func_sum)

# %%
sigma_noise = jnp.ones(nx*nx) * sigma

# %%
start = time.time()
ll = loss_func_batched(vol_fourier, angles_true[:20], shifts_true[:20], ctf_params[:20], imgs[:20], sigma_noise)
#ll = loss_func_batched(np.random.randn(nx,nx,nx), angles_true[:20], shifts_true[:20], ctf_params[:20], imgs[:20])
print(time.time()-start)
print(ll.shape)
# Out:
# 5.666037321090698
# (20,)

# %% [markdown]
# Gradients with respect to volume pixels, over all (or a batch of) images

# %%
start = time.time()
ll = grad_loss_volume(np.random.randn(nx,nx,nx), angles_true[0],  shifts_true[0], ctf_params[0], imgs[0], sigma_noise)
print(time.time()-start)
print(ll.shape)
# Out:
# 1.6631784439086914
# (32, 32, 32)

# %%
batch_size = N
idx = np.random.default_rng().choice(N, size=batch_size, replace = False)

start = time.time()
ll = grad_loss_volume_sum(np.random.randn(nx,nx,nx), angles_true[idx], shifts_true[idx], ctf_params[idx], imgs[idx], sigma_noise)
print(time.time()-start)
print(ll.shape)
# Out:
# 2.2958621978759766
# (32, 32, 32)

# %% [markdown]
# ### MCMC - vol

# %%
vol_fourier.shape
# Out:
# (32, 32, 32)

# %%
def plot_true_vs_estimated(vol_true, vol_estimated):

    plt.rcParams["figure.figsize"]=16,16
    plt.subplot(2,2,1)
    plt.imshow(jnp.abs(jnp.fft.fftshift(vol_true[:,:,0]))); plt.colorbar()
    plt.title('True')
    plt.subplot(2,2,2)
    plt.imshow(jnp.abs(jnp.fft.fftshift(vol_estimated[:,:,0]))); plt.colorbar()
    plt.title('Sampled')
    plt.subplot(2,2,3)
    plt.imshow(jnp.real(jnp.fft.fftshift(jnp.fft.ifftn(vol_true[:,:,0])))); 
    plt.colorbar()
    plt.title('True')
    plt.subplot(2,2,4)
    plt.imshow(jnp.real(jnp.fft.fftshift(jnp.fft.ifftn(vol_estimated[:,:,0])))); 
    plt.colorbar()
    plt.title('Estimated')

    plt.rcParams["figure.figsize"]=8,8

# %%
#alpha = 1e-10
#alpha = 0.001



radius_mask = 0.75 # nx=16
#radius = 0.8 # for nx=32
#radius = 1.6 # for nx=64
#radius = 3.2 # for nx=128)
mask = create_3d_mask(x_grid, (0,0,0), radius_mask)
mip_z(jnp.fft.fftshift(mask)); plt.colorbar()

slice_func,slice_func_array, slice_func_array_angles = get_slice_funcs(project, x_grid, mask, "tri")

loss_func, loss_func_batched, loss_func_sum, _ = get_loss_funcs(slice_func, alpha = alpha)
grad_loss_volume, grad_loss_volume_sum = get_grad_v_funcs(loss_func, loss_func_sum)

logPi = lambda v : -loss_func_sum(v, angles_rec, shifts_true, ctf_params, imgs, 1)
gradLogPi = lambda v : -jnp.conj(grad_loss_volume_sum(v, angles_rec, shifts_true, ctf_params, imgs, 1))

# %%
alpha
# Out:
# 0.01

# %%
dt_list = jnp.array([0.5])
L = 10
M = 1

@jax.jit
def proposal_hmc_jit(key, x0):
    return proposal_hmc(key, x0, logPi, gradLogPi, dt_list, L, M)

# %%
N_mc_samples = 41

key = random.PRNGKey(int(jnp.floor(np.random.rand()*1000)))
v0 = jnp.array(np.random.randn(nx,nx,nx) + 1j * np.random.randn(nx,nx,nx)) 
#v0 = v_rec

t0 = time.time()
v_hmc_mean, r_hmc, v_hmc_samples = mcmc(key, proposal_hmc_jit, v0, N_mc_samples, logPi)
print((time.time() - t0)/N_mc_samples)
v_hmc_mean = v_hmc_mean * mask
# Out:
#   Iter 20 , a =  1.0
#   MC sample 20 , loss (of mean) = 1518604.05834707
#   Iter 40 , a =  0.7226031956801297
#   MC sample 40 , loss (of mean) = 1516776.0628889888
# 0.3245431271994986

# %%
plt.plot(r_hmc)

# %%
plot_true_vs_estimated(vol_fourier, v_hmc_mean)

# %%
print(loss_func_sum(vol_fourier, angles_true, shifts_true, ctf_params, imgs, 1))
print(loss_func_sum(v_hmc_mean, angles_rec, shifts_true, ctf_params, imgs, 1))
#print(loss_func_sum(v_rec, angles_rec, shifts_true, ctf_params, imgs, 1))
#print(loss_func_sum(vcg1, angles_rec, shifts_true, ctf_params, imgs, 1))
# Out:
# 1502557.17884119
# 1514067.1703557626

# %% [markdown]
# ### MCMC - orientations

# %%
alpha0 = 0

radius = 0.4
mask = create_3d_mask(x_grid, (0,0,0),radius)
#mip_z(jnp.fft.fftshift(mask)); plt.colorbar()

slice_func,slice_func_array, slice_func_array_angles = get_slice_funcs(project, x_grid, mask, "tri")
loss_func, loss_func_batched, loss_func_sum, _ = get_loss_funcs(slice_func, alpha = alpha0)
logPi_batch = lambda a : -loss_func_batched(vol_fourier, a, shifts_true, ctf_params, imgs, 1)

def proposal_uniform_orientations_func(key, x0):
    return proposal_uniform_orientations(key, x0, logPi_batch)

# %%
key = random.PRNGKey(int(jnp.floor(np.random.rand()*1000)))
N_mc_samples = 1001

angles0 = generate_uniform_orientations_jax(key, N)
t0 = time.time()
angles_mean, r_samples_angles, samples_angles = mcmc(key, proposal_uniform_orientations_func, angles0, N_mc_samples, logPi_batch, N)
print(time.time() - t0)

angles_rec = samples_angles[0]
# Out:
#   MC sample 100 , loss = 1505392.7477273722
#   MC sample 200 , loss = 1499942.0986200569
#   MC sample 300 , loss = 1497117.3355399508
#   MC sample 400 , loss = 1495357.1026216724
#   MC sample 500 , loss = 1494026.7731443157
#   MC sample 600 , loss = 1493032.9848531063
#   MC sample 700 , loss = 1492355.393501351
#   MC sample 800 , loss = 1491672.4334722897
#   MC sample 900 , loss = 1491130.1652607739
#   MC sample 1000 , loss = 1490654.016007777
# 49.83778977394104

# %%
key, *keys = random.split(key, N_mc_samples + 1)
angles0 = generate_uniform_orientations_jax(key, N)
#print(jnp.mean(loss_angles(angles0))/(nx*nx*jnp.max(jnp.abs(imgs))))
print(jnp.max(jnp.abs(logPi_batch(angles0))))

t0 = time.time()
for i in range(N_mc_samples):
    angles1 = mcmc_batch_step(keys[i], N_mc_samples, logPi_batch, angles0)
    angles0 = angles1
    
    if jnp.mod(i, 100) == 0:
        #loss_i = jnp.mean(loss_angles(angles1))/(nx*nx*jnp.max(jnp.abs(imgs)))
        loss_i = jnp.max(jnp.abs(logPi_batch(angles1)))
        print("Iter", i, ", loss = " ,loss_i)
        
print(time.time()-t0)
# Out:
# 1817322.1448786615
# Iter 0 , loss =  1798915.4524078316
# Iter 100 , loss =  1694530.4329539621
# Iter 200 , loss =  1694530.4329539621
# Iter 300 , loss =  1676713.6302346857
# Iter 400 , loss =  1676713.6302346857
# Iter 500 , loss =  1668790.5203267203
# Iter 600 , loss =  1668790.5203267203
# Iter 700 , loss =  1667220.8750247858
# Iter 800 , loss =  1667220.8750247858
# Iter 900 , loss =  1667220.8750247858
# Iter 1000 , loss =  1667220.8750247858
# 49.60457730293274

# %%
angles0 = generate_uniform_orientations_jax(key, N)

print(jnp.max(jnp.abs(logPi_batch(angles0))))
print(jnp.max(jnp.abs(logPi_batch(angles_true))))
print(jnp.max(jnp.abs(logPi_batch(angles1))))
print(jnp.max(jnp.abs(logPi_batch(angles_rec))))
# Out:
# 1817322.1448786615
# 1657585.0466964685
# 1667220.8750247858
# 1673476.6783362867

# %% [markdown]
# ### MCMC shifts

# %% [markdown]
# #### Naive

# %%
alpha0 = 0
B = pixel_size*nx/10

radius = 0.4
mask = create_3d_mask(x_grid, (0,0,0),radius)
#mip_z(jnp.fft.fftshift(mask)); plt.colorbar()

slice_func,slice_func_array, slice_func_array_angles = get_slice_funcs(project, x_grid, mask, "tri")
loss_func, loss_func_batched, loss_func_sum, _ = get_loss_funcs(slice_func, alpha = alpha0)
logPi_shifts = lambda sh : -loss_func_batched(vol_fourier, angles_true, sh, ctf_params, imgs, 1)


def proposal_uniform_shifts_func(key, x0):
    return proposal_uniform_shifts(key, x0, logPi_shifts, B)

# %%
B
# Out:
# 2.0

# %%
key = random.PRNGKey(int(jnp.floor(np.random.rand()*1000)))
N_mc_samples = 2001

shifts0 = generate_uniform_shifts(key, N, B)
t0 = time.time()
_, r_samples_shifts, shifts_samples = mcmc(key, proposal_uniform_shifts_func, shifts0, N_mc_samples, logPi_shifts, N)
print(time.time()-t0)

shifts_rec = shifts_samples[0]

# %%
plt.plot(r_samples_shifts[:,10])

# %%
shifts_err = wrap_arround_distance_2d_array(shifts_true, shifts_rec, B)
print("mean shift error =", jnp.mean(shifts_err), "in [", -B, ",", B, "]^2")
plt.plot(shifts_err)
# Out:
# mean shift error = 0.2606278306450639 in [ -10.0 , 10.0 ]^2

# %% [markdown]
# #### Optimised

# %%
alpha0 = 0
B = pixel_size*nx/10

radius = 0.4
mask = create_3d_mask(x_grid, (0,0,0),radius)
#mip_z(jnp.fft.fftshift(mask)); plt.colorbar()

proj = jax.vmap(rotate_and_interpolate, in_axes=(None,0,None,None))(vol_fourier*mask, angles_true, x_grid, x_grid)

# %%
from src.projection import apply_shifts_and_ctf
from src.jaxops import *

loss_proj_func_batched = get_loss_proj_funcs(apply_shifts_and_ctf, x_grid, alpha = alpha0)
logPi_shifts = lambda sh : -loss_proj_func_batched(vol_fourier, proj, sh, ctf_params, imgs, 1)

@jax.jit
def proposal_uniform_shifts_func(key, x0):
    return proposal_uniform_shifts(key, x0, logPi_shifts, B)

@jax.jit
def proposal_gaussian_shifts_func(key, x0):
    return proposal_gaussian_shifts(key, x0, logPi_shifts, B)

# %%
key = random.PRNGKey(int(jnp.floor(np.random.rand()*1000)))
N_mc_samples = 101

shifts0 = generate_gaussian_shifts(key, N, B)
t0 = time.time()
_, r_samples_shifts, shifts_samples = mcmc(key, proposal_gaussian_shifts_func, shifts0, N_mc_samples, logPi_shifts, N)
print(time.time()-t0)

shifts_rec = shifts_samples[0]
# Out:
#   MC sample 100 , loss = 1491121.6395698076
# 1.5344204902648926

# %%
plt.plot(r_samples_shifts[:,10])

# %%
shifts_err = wrap_arround_distance_2d_array(shifts_true, shifts_rec, B)
print("mean shift error =", jnp.mean(shifts_err), "in [", -B, ",", B, "]^2")
plt.plot(shifts_err)
# Out:
# mean shift error = 0.4757312914767468 in [ -2.0 , 2.0 ]^2

# %% [markdown]
# ### Ab initio

# %%
sh = generate_gaussian_shifts(key, N, nx*pixel_size/10)
plt.plot(shifts_true[:,0], shifts_true[:,1],'.')
plt.plot(sh[:,0], sh[:,1],'.')

# %%
key = random.PRNGKey(int(jnp.floor(np.random.rand()*1000)))

N_samples = 1000
N_iter = 100000

dr = 0.05
radius = 0.2
#alpha = 0.001
alpha = 1e-7

use_sgd = True

N_cg_iter = 1000

N_sgd_iter = 100
batch_size = 500
learning_rate = 1
P = None

if use_sgd:
    N_vol_iter = N_sgd_iter
else:
    N_vol_iter = N_cg_iter

vol0 = None
angles0 = None
shifts0 = None
    
N_samples_vol = 101
N_samples_angles = 1000
N_samples_shifts = 1000

eps_vol = 2e-5

# HMC params
dt_list = jnp.array([0.1, 0.5, 1, 5])
L = 10

# boundary for sampling shifts in [-B, B]^2
B = pixel_size*nx/10

out_dir = '../data/ab_initio/'
imgs = imgs.reshape([N, nx*nx])
#v_rec, angles_rec = ab_initio(project, imgs, sigma_noise, shifts_true, ctf_params, x_grid, use_sgd, N_iter, N_vol_iter, learning_rate, batch_size, P, N_samples, radius, dr, alpha, eps_vol, 'tri', True, True, True, out_dir)
v_rec, angles_rec, shifts_rec = ab_initio_mcmc(key, 
                                   project, 
                                   rotate_and_interpolate,
                                   apply_shifts_and_ctf,
                                   imgs, 
                                   sigma_noise, 
                                   ctf_params, 
                                   x_grid, 
                                   use_sgd, 
                                   vol0,
                                   angles0,
                                   shifts0,
                                   N_iter, 
                                   learning_rate, 
                                   batch_size, 
                                   P, 
                                   N_samples_vol,
                                   N_samples_angles, 
                                   N_samples_shifts,
                                   dt_list, 
                                   L, 
                                   radius, 
                                   dr, 
                                   alpha, 
                                   eps_vol,
                                   B,
                                   'tri', 
                                   True, True, True, out_dir)
# Out:
# Fourier radius: 0.8
# Starting radius: 0.2
# Frequency marching step size: 0.05
# Number of frequency marching steps: 13
# ------------------------------------
#
# Initialitsing volume
#   sgd epoch 0: mean gradient = 2.986591822960498e-05
#   sgd epoch 10: mean gradient = 2.9349551950540272e-05
#   sgd epoch 20: mean gradient = 3.002409720013652e-05
#   sgd epoch 30: mean gradient = 2.9210826088989494e-05
#   sgd epoch 40: mean gradient = 2.7940770914880903e-05
#   sgd epoch 50: mean gradient = 2.792229251533544e-05
#   sgd epoch 60: mean gradient = 2.6727275863849047e-05
#   sgd epoch 70: mean gradient = 2.678946162913698e-05
#   sgd epoch 80: mean gradient = 2.4545175570656496e-05
#   sgd epoch 90: mean gradient = 2.5866278636951368e-05
#   sgd epoch 100: mean gradient = 2.6997337963565946e-05
#   sgd epoch 110: mean gradient = 2.487652288729334e-05
#   sgd epoch 120: mean gradient = 2.5213537171507055e-05
#   sgd epoch 130: mean gradient = 2.396312731062094e-05
#   sgd epoch 140: mean gradient = 2.27070186040888e-05
#   sgd epoch 150: mean gradient = 2.255124526235864e-05
#   sgd epoch 160: mean gradient = 2.3249409164730936e-05
#   sgd epoch 170: mean gradient = 2.500262790576097e-05
#   sgd epoch 180: mean gradient = 2.1027498998811107e-05
#   sgd epoch 190: mean gradient = 2.265392231769132e-05
#   sgd epoch 200: mean gradient = 2.0619929745817208e-05
#   sgd epoch 210: mean gradient = 2.1722443834725408e-05
#   sgd epoch 220: mean gradient = 2.1637868767818898e-05
#   sgd epoch 230: mean gradient = 2.176367355973892e-05
#   sgd epoch 240: mean gradient = 2.2255340315403095e-05
#   sgd epoch 250: mean gradient = 1.9332565047710055e-05
# Iter  0
# Sampling orientations
#   MC sample 100 , loss = 172.13678699426583
#   MC sample 200 , loss = 172.13675719693313
#   MC sample 300 , loss = 172.0989936076089
#   MC sample 400 , loss = 172.12887172995275
#   MC sample 500 , loss = 172.1401818775215
#   MC sample 600 , loss = 172.12442522789567
#   MC sample 700 , loss = 172.1359796271773
#   MC sample 800 , loss = 172.1148308584546
#   MC sample 900 , loss = 172.11095583626468
#   Time orientations sampling = 12.201976537704468
#   mean(a_angles) = 0.49518880384390607
# Sampling shifts
#   MC sample 100 , loss = 155.27936662179894
#   MC sample 200 , loss = 154.94985918897572
#   MC sample 300 , loss = 154.80148049667196
#   MC sample 400 , loss = 154.77859997781962
#   MC sample 500 , loss = 154.73477039974017
#   MC sample 600 , loss = 154.73654281411638
#   MC sample 700 , loss = 154.71584788934595
#   MC sample 800 , loss = 154.70253366018363
#   MC sample 900 , loss = 154.71142892438127
#   Time shifts sampling = 8.5050950050354
#   mean(a_shifts) = 0.0425809133385182
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 64.84708666065183
#   Time volume sampling = 18.783629894256592
#   mean(a_vol) = 0.6581071260864055
# 2022-03-18 17:23:22.009005
#   nx = 10
# Iter  1
# Sampling orientations
#   MC sample 100 , loss = 103.60736896954388
#   MC sample 200 , loss = 103.63195407360705
#   MC sample 300 , loss = 103.62949764914245
#   MC sample 400 , loss = 103.63190633134221
#   MC sample 500 , loss = 103.6171135593322
#   MC sample 600 , loss = 103.62260150583917
#   MC sample 700 , loss = 103.64626502893847
#   MC sample 800 , loss = 103.61250220947892
#   MC sample 900 , loss = 103.63986896369977
#   Time orientations sampling = 13.178635358810425
#   mean(a_angles) = 0.46350900286977526
# Sampling shifts
#   MC sample 100 , loss = 99.2775906860055
#   MC sample 200 , loss = 98.43841750318003
#   MC sample 300 , loss = 98.0401349226702
#   MC sample 400 , loss = 97.80865757815756
#   MC sample 500 , loss = 97.66160066872449
#   MC sample 600 , loss = 97.54909821266052
#   MC sample 700 , loss = 97.46744105287482
#   MC sample 800 , loss = 97.38796189801772
#   MC sample 900 , loss = 97.34195231036671
#   Time shifts sampling = 8.78322148323059
#   mean(a_shifts) = 0.006996836901798523
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 96.8405883749681
#   Time volume sampling = 20.218705892562866
#   mean(a_vol) = 0.7571313927104711
# Iter  2
# Sampling orientations
#   MC sample 100 , loss = 95.22499119962161
#   MC sample 200 , loss = 95.15718084305418
#   MC sample 300 , loss = 95.09614792579002
#   MC sample 400 , loss = 95.09339612689601
#   MC sample 500 , loss = 95.09401143103324
#   MC sample 600 , loss = 95.05805870149776
#   MC sample 700 , loss = 95.06194015260695
#   MC sample 800 , loss = 95.05418484063752
#   MC sample 900 , loss = 95.08731032693217
#   Time orientations sampling = 13.242733001708984
#   mean(a_angles) = 0.2319263282936554
# Sampling shifts
#   MC sample 100 , loss = 95.02277159619231
#   MC sample 200 , loss = 94.97110477667779
#   MC sample 300 , loss = 94.92788178956286
#   MC sample 400 , loss = 94.90722883723751
#   MC sample 500 , loss = 94.86980290615756
#   MC sample 600 , loss = 94.85147941330851
#   MC sample 700 , loss = 94.83855697016006
#   MC sample 800 , loss = 94.80355738010604
#   MC sample 900 , loss = 94.79875112091867
#   Time shifts sampling = 8.643153429031372
#   mean(a_shifts) = 0.005113726479476352
# Sampling the volume
#   Iter 100 , a =  0.9760930648256463
#   MC sample 100 , loss (of mean) = 93.55788496684086
#   Time volume sampling = 20.236868858337402
#   mean(a_vol) = 0.7262512546108323
# Iter  3
# Sampling orientations
#   MC sample 100 , loss = 90.24974331573698
#   MC sample 200 , loss = 89.74852976951082
#   MC sample 300 , loss = 89.53547369623404
#   MC sample 400 , loss = 89.3852336556346
#   MC sample 500 , loss = 89.24877077537391
#   MC sample 600 , loss = 89.18929666351458
#   MC sample 700 , loss = 89.15611359740527
#   MC sample 800 , loss = 89.1145539617243
#   MC sample 900 , loss = 89.03270699692278
#   Time orientations sampling = 13.30398154258728
#   mean(a_angles) = 0.036587936916425104
# Sampling shifts
#   MC sample 100 , loss = 88.94085717420944
#   MC sample 200 , loss = 88.89078722181576
#   MC sample 300 , loss = 88.84540357365967
#   MC sample 400 , loss = 88.82185706657707
#   MC sample 500 , loss = 88.80087697052883
#   MC sample 600 , loss = 88.79264868397208
#   MC sample 700 , loss = 88.79032086608909
#   MC sample 800 , loss = 88.76311729601822
#   MC sample 900 , loss = 88.76079889972301
#   Time shifts sampling = 8.596150159835815
#   mean(a_shifts) = 0.004514129082781341
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 87.23199841850861
#   Time volume sampling = 21.86878204345703
#   mean(a_vol) = 0.8164765823599055
# Iter  4
# Sampling orientations
#   MC sample 100 , loss = 86.24501432032348
#   MC sample 200 , loss = 85.94215135431597
#   MC sample 300 , loss = 85.72534894989764
#   MC sample 400 , loss = 85.61128988377548
#   MC sample 500 , loss = 85.49939302048432
#   MC sample 600 , loss = 85.45764072234466
#   MC sample 700 , loss = 85.40906528725431
#   MC sample 800 , loss = 85.36731744547912
#   MC sample 900 , loss = 85.31802476910462
#   Time orientations sampling = 13.23213267326355
#   mean(a_angles) = 0.010686125960172507
# Sampling shifts
#   MC sample 100 , loss = 85.20782317957676
#   MC sample 200 , loss = 85.17658046835655
#   MC sample 300 , loss = 85.14709857936208
#   MC sample 400 , loss = 85.14449552713143
#   MC sample 500 , loss = 85.13093333807632
#   MC sample 600 , loss = 85.13469742760999
#   MC sample 700 , loss = 85.12087673588896
#   MC sample 800 , loss = 85.09733900862103
#   MC sample 900 , loss = 85.07812740724636
#   Time shifts sampling = 8.675168752670288
#   mean(a_shifts) = 0.004096187134212003
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 84.73324031899523
#   Time volume sampling = 20.149584770202637
#   mean(a_vol) = 0.7164080897518335
# Iter  5
# Sampling orientations
#   MC sample 100 , loss = 114.42711724335615
#   MC sample 200 , loss = 114.2741537714965
#   MC sample 300 , loss = 114.18173498471029
#   MC sample 400 , loss = 114.09833876310977
#   MC sample 500 , loss = 114.0330589386845
#   MC sample 600 , loss = 113.94133593932689
#   MC sample 700 , loss = 113.89023722611769
#   MC sample 800 , loss = 113.849153989959
#   MC sample 900 , loss = 113.84319572979338
#   Time orientations sampling = 13.17896556854248
#   mean(a_angles) = 0.005629675943564439
# Sampling shifts
#   MC sample 100 , loss = 113.75410227970127
#   MC sample 200 , loss = 113.7393576314973
#   MC sample 300 , loss = 113.71591188055078
#   MC sample 400 , loss = 113.70856526920167
#   MC sample 500 , loss = 113.67911789528146
#   MC sample 600 , loss = 113.6620254002736
#   MC sample 700 , loss = 113.66064228355906
#   MC sample 800 , loss = 113.65019556067485
#   MC sample 900 , loss = 113.64170855893867
#   Time shifts sampling = 10.459847688674927
#   mean(a_shifts) = 0.0037604786386898304
# Sampling the volume
#   Iter 100 , a =  0.0
#   MC sample 100 , loss (of mean) = 112.78137903452321
#   Time volume sampling = 20.21036696434021
#   mean(a_vol) = 0.7863601121635543
# Iter  6
# Sampling orientations
#   MC sample 100 , loss = 112.6278362303169
#   MC sample 200 , loss = 112.49156480453304
#   MC sample 300 , loss = 112.43674071025369
#   MC sample 400 , loss = 112.35381096223361
#   MC sample 500 , loss = 112.2934496896735
#   MC sample 600 , loss = 112.21395498358189
#   MC sample 700 , loss = 112.17360009848304
#   MC sample 800 , loss = 112.1434677387305
#   MC sample 900 , loss = 112.09427671761304
#   Time orientations sampling = 13.206824541091919
#   mean(a_angles) = 0.003599774715884396
# Sampling shifts
#   MC sample 100 , loss = 112.02010011298792
#   MC sample 200 , loss = 111.98323313103523
#   MC sample 300 , loss = 111.9677080671745
#   MC sample 400 , loss = 111.95617871180175
#   MC sample 500 , loss = 111.95291361484821
#   MC sample 600 , loss = 111.94943113810555
#   MC sample 700 , loss = 111.93051887237756
#   MC sample 800 , loss = 111.92213871081053
#   MC sample 900 , loss = 111.92553422423998
#   Time shifts sampling = 8.795986652374268
#   mean(a_shifts) = 0.0035024713753699804
# Sampling the volume
#   Iter 100 , a =  0.0
#   MC sample 100 , loss (of mean) = 111.7655200480248
#   Time volume sampling = 20.176949977874756
#   mean(a_vol) = 0.7266204038900059
# Iter  7
# Sampling orientations
#   MC sample 100 , loss = 111.7858172594726
#   MC sample 200 , loss = 111.70768756192854
#   MC sample 300 , loss = 111.67565088816882
#   MC sample 400 , loss = 111.61943767776962
#   MC sample 500 , loss = 111.6042345452014
#   MC sample 600 , loss = 111.55335089932113
#   MC sample 700 , loss = 111.53139205395868
#   MC sample 800 , loss = 111.50227049226655
#   MC sample 900 , loss = 111.49486775227771
#   Time orientations sampling = 13.266851425170898
#   mean(a_angles) = 0.0026759861502599854
# Sampling shifts
#   MC sample 100 , loss = 111.4351077171101
#   MC sample 200 , loss = 111.42184483949754
#   MC sample 300 , loss = 111.38928625707418
#   MC sample 400 , loss = 111.39632840347817
#   MC sample 500 , loss = 111.38771311703381
#   MC sample 600 , loss = 111.3963811284665
#   MC sample 700 , loss = 111.40195818847046
#   MC sample 800 , loss = 111.38798404077534
#   MC sample 900 , loss = 111.38726302022539
#   Time shifts sampling = 8.662084817886353
#   mean(a_shifts) = 0.0033787316159550464
# Sampling the volume
#   Iter 100 , a =  0.9945029174255308
#   MC sample 100 , loss (of mean) = 111.33316708000875
#   Time volume sampling = 20.227957487106323
#   mean(a_vol) = 0.6864266091322435
# Iter  8
# Sampling orientations
#   MC sample 100 , loss = 111.382843106524
#   MC sample 200 , loss = 111.36153513891895
#   MC sample 300 , loss = 111.30234098207792
#   MC sample 400 , loss = 111.28021961479537
#   MC sample 500 , loss = 111.27413864965078
#   MC sample 600 , loss = 111.24797093903926
#   MC sample 700 , loss = 111.20938078701303
#   MC sample 800 , loss = 111.17581396050714
#   MC sample 900 , loss = 111.12085268622661
#   Time orientations sampling = 13.333500385284424
#   mean(a_angles) = 0.002323106262945014
# Sampling shifts
#   MC sample 100 , loss = 111.0776329922955
#   MC sample 200 , loss = 111.04980959823824
#   MC sample 300 , loss = 111.03431989343842
#   MC sample 400 , loss = 111.0086019581531
#   MC sample 500 , loss = 110.98827456337204
#   MC sample 600 , loss = 110.99464587036593
#   MC sample 700 , loss = 111.01559688728899
#   MC sample 800 , loss = 111.00244261729033
#   MC sample 900 , loss = 110.99502033158679
#   Time shifts sampling = 8.633584260940552
#   mean(a_shifts) = 0.0033299847239962326
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 110.96033538411163
#   Time volume sampling = 22.013468503952026
#   mean(a_vol) = 0.6865428475563102
# 2022-03-18 17:29:14.785883
#   nx = 12
# Iter  9
# Sampling orientations
#   MC sample 100 , loss = 149.57475924306374
#   MC sample 200 , loss = 149.53605078242086
#   MC sample 300 , loss = 149.50573746568784
#   MC sample 400 , loss = 149.47490706355825
#   MC sample 500 , loss = 149.4598341725311
#   MC sample 600 , loss = 149.44248128301726
#   MC sample 700 , loss = 149.410990004468
#   MC sample 800 , loss = 149.39580573613608
#   MC sample 900 , loss = 149.38830199260846
#   Time orientations sampling = 16.201313734054565
#   mean(a_angles) = 0.0020297317089022354
# Sampling shifts
#   MC sample 100 , loss = 149.3531624177632
#   MC sample 200 , loss = 149.32047599253633
#   MC sample 300 , loss = 149.31757447903342
#   MC sample 400 , loss = 149.32638070813508
#   MC sample 500 , loss = 149.32168255895166
#   MC sample 600 , loss = 149.32087099165625
#   MC sample 700 , loss = 149.3211341852415
#   MC sample 800 , loss = 149.32168604985188
#   MC sample 900 , loss = 149.30792386428857
#   Time shifts sampling = 9.072447299957275
#   mean(a_shifts) = 0.0032932084921608335
# Sampling the volume
#   Iter 100 , a =  0.9926258205296403
#   MC sample 100 , loss (of mean) = 148.4176528751742
#   Time volume sampling = 25.790132999420166
#   mean(a_vol) = 0.7546767852453065
# Iter  10
# Sampling orientations
#   MC sample 100 , loss = 148.4673214731331
#   MC sample 200 , loss = 148.40284119081818
#   MC sample 300 , loss = 148.32960209819834
#   MC sample 400 , loss = 148.2894514385112
#   MC sample 500 , loss = 148.24682058481713
#   MC sample 600 , loss = 148.19115884384703
#   MC sample 700 , loss = 148.158694482508
#   MC sample 800 , loss = 148.12850145379295
#   MC sample 900 , loss = 148.11659515091276
#   Time orientations sampling = 16.154489755630493
#   mean(a_angles) = 0.001702060022815766
# Sampling shifts
#   MC sample 100 , loss = 148.04430418639473
#   MC sample 200 , loss = 148.0204116989474
#   MC sample 300 , loss = 147.99107449790762
#   MC sample 400 , loss = 147.97674486333318
#   MC sample 500 , loss = 147.96973584170203
#   MC sample 600 , loss = 147.95224493266605
#   MC sample 700 , loss = 147.95704354106425
#   MC sample 800 , loss = 147.95494849138825
#   MC sample 900 , loss = 147.94692570911963
#   Time shifts sampling = 8.860623121261597
#   mean(a_shifts) = 0.0030326348736495635
# Sampling the volume
#   Iter 100 , a =  0.9976023516654812
#   MC sample 100 , loss (of mean) = 147.77142065401281
#   Time volume sampling = 27.8486385345459
#   mean(a_vol) = 0.7455267563441424
# Iter  11
# Sampling orientations
#   MC sample 100 , loss = 147.8863171203053
#   MC sample 200 , loss = 147.83713931149995
#   MC sample 300 , loss = 147.79468657191882
#   MC sample 400 , loss = 147.76138262507925
#   MC sample 500 , loss = 147.72996446144037
#   MC sample 600 , loss = 147.69476863420581
#   MC sample 700 , loss = 147.6522157965572
#   MC sample 800 , loss = 147.61864857318548
#   MC sample 900 , loss = 147.60544326304162
#   Time orientations sampling = 16.295434951782227
#   mean(a_angles) = 0.0013897601046495968
# Sampling shifts
#   MC sample 100 , loss = 147.57147705019568
#   MC sample 200 , loss = 147.54658747999488
#   MC sample 300 , loss = 147.53247500379015
#   MC sample 400 , loss = 147.51980709963098
#   MC sample 500 , loss = 147.512631903402
#   MC sample 600 , loss = 147.50993248787194
#   MC sample 700 , loss = 147.51504088629454
#   MC sample 800 , loss = 147.49874917144842
#   MC sample 900 , loss = 147.49444058083026
#   Time shifts sampling = 8.904030799865723
#   mean(a_shifts) = 0.0029788050925206983
# Sampling the volume
#   Iter 100 , a =  0.9971959863436504
#   MC sample 100 , loss (of mean) = 147.37632088512163
#   Time volume sampling = 25.992769241333008
#   mean(a_vol) = 0.7646419207204282
# Iter  12
# Sampling orientations
#   MC sample 100 , loss = 147.54874257070182
#   MC sample 200 , loss = 147.51875500003098
#   MC sample 300 , loss = 147.4932551874244
#   MC sample 400 , loss = 147.4798001802603
#   MC sample 500 , loss = 147.45029037989994
#   MC sample 600 , loss = 147.42059057426798
#   MC sample 700 , loss = 147.38599816561967
#   MC sample 800 , loss = 147.36851518923157
#   MC sample 900 , loss = 147.36675208758666
#   Time orientations sampling = 16.150667905807495
#   mean(a_angles) = 0.001220351888297346
# Sampling shifts
#   MC sample 100 , loss = 147.33979353358527
#   MC sample 200 , loss = 147.31866226441818
#   MC sample 300 , loss = 147.3005829806583
#   MC sample 400 , loss = 147.295399691746
#   MC sample 500 , loss = 147.28675387841915
#   MC sample 600 , loss = 147.30017428252202
#   MC sample 700 , loss = 147.28360122151756
#   MC sample 800 , loss = 147.25915085140335
#   MC sample 900 , loss = 147.2501477738694
#   Time shifts sampling = 11.04033613204956
#   mean(a_shifts) = 0.0029408537003944787
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 147.0977372913138
#   Time volume sampling = 25.88290047645569
#   mean(a_vol) = 0.804404403035492
# Iter  13
# Sampling orientations
#   MC sample 100 , loss = 196.5132795701767
#   MC sample 200 , loss = 196.4831612109098
#   MC sample 300 , loss = 196.44172747269496
#   MC sample 400 , loss = 196.39918879156883
#   MC sample 500 , loss = 196.37943295771063
#   MC sample 600 , loss = 196.34601736556527
#   MC sample 700 , loss = 196.3284502243928
#   MC sample 800 , loss = 196.31327997493074
#   MC sample 900 , loss = 196.30593207416857
#   Time orientations sampling = 17.954606294631958
#   mean(a_angles) = 0.0011350274599044943
# Sampling shifts
#   MC sample 100 , loss = 196.27297222806246
#   MC sample 200 , loss = 196.25598652451157
#   MC sample 300 , loss = 196.23723144773228
#   MC sample 400 , loss = 196.23852392750103
#   MC sample 500 , loss = 196.24318885529564
#   MC sample 600 , loss = 196.246781081379
#   MC sample 700 , loss = 196.26536179973303
#   MC sample 800 , loss = 196.26030101527428
#   MC sample 900 , loss = 196.24220458107865
#   Time shifts sampling = 9.303284406661987
#   mean(a_shifts) = 0.002877260043096179
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 195.77487721006602
#   Time volume sampling = 29.90723180770874
#   mean(a_vol) = 0.794882621673759
# Iter  14
# Sampling orientations
#   MC sample 100 , loss = 196.0762233949592
#   MC sample 200 , loss = 196.04945791192213
#   MC sample 300 , loss = 196.00530194100966
#   MC sample 400 , loss = 195.97959801100723
#   MC sample 500 , loss = 195.9503817996788
#   MC sample 600 , loss = 195.92274068047053
#   MC sample 700 , loss = 195.89725217623374
#   MC sample 800 , loss = 195.86887569546766
#   MC sample 900 , loss = 195.87402518223908
#   Time orientations sampling = 19.76737356185913
#   mean(a_angles) = 0.001000678147736631
# Sampling shifts
#   MC sample 100 , loss = 195.80167018189366
#   MC sample 200 , loss = 195.7866697321408
#   MC sample 300 , loss = 195.77060958302178
#   MC sample 400 , loss = 195.76069347003553
#   MC sample 500 , loss = 195.72672602765255
#   MC sample 600 , loss = 195.7085189254958
#   MC sample 700 , loss = 195.6885885057518
#   MC sample 800 , loss = 195.70879264967513
#   MC sample 900 , loss = 195.69800357210835
#   Time shifts sampling = 9.223645210266113
#   mean(a_shifts) = 0.0027911695116389044
# Sampling the volume
#   Iter 100 , a =  0.9996671984706795
#   MC sample 100 , loss (of mean) = 195.45741959576407
#   Time volume sampling = 29.603720903396606
#   mean(a_vol) = 0.6447558264112317
# Iter  15
# Sampling orientations
#   MC sample 100 , loss = 195.78332255141018
#   MC sample 200 , loss = 195.742486866551
#   MC sample 300 , loss = 195.7092188609032
#   MC sample 400 , loss = 195.68699457395036
#   MC sample 500 , loss = 195.65842026702498
#   MC sample 600 , loss = 195.63148457489007
#   MC sample 700 , loss = 195.61555958839463
#   MC sample 800 , loss = 195.59607167837692
#   MC sample 900 , loss = 195.58424731652784
#   Time orientations sampling = 17.905539751052856
#   mean(a_angles) = 0.0009104119372486509
# Sampling shifts
#   MC sample 100 , loss = 195.54766191428396
#   MC sample 200 , loss = 195.52880561142715
#   MC sample 300 , loss = 195.50936560500162
#   MC sample 400 , loss = 195.50775803408385
#   MC sample 500 , loss = 195.51075124666457
#   MC sample 600 , loss = 195.49804392378815
#   MC sample 700 , loss = 195.49650439136454
#   MC sample 800 , loss = 195.50839247916355
#   MC sample 900 , loss = 195.51080271009923
#   Time shifts sampling = 9.294728994369507
#   mean(a_shifts) = 0.002708164754251595
# Sampling the volume
#   Iter 100 , a =  0.9990893944604246
#   MC sample 100 , loss (of mean) = 195.25370669409716
#   Time volume sampling = 31.524787425994873
#   mean(a_vol) = 0.7630358746665769
# Iter  16
# Sampling orientations
#   MC sample 100 , loss = 195.5683696112192
#   MC sample 200 , loss = 195.54269450023244
#   MC sample 300 , loss = 195.5077192398671
#   MC sample 400 , loss = 195.4880980650494
#   MC sample 500 , loss = 195.44937618803354
#   MC sample 600 , loss = 195.4342073141409
#   MC sample 700 , loss = 195.4209185988417
#   MC sample 800 , loss = 195.40856652609065
#   MC sample 900 , loss = 195.3831076249803
#   Time orientations sampling = 18.051014184951782
#   mean(a_angles) = 0.0008333698205493923
# Sampling shifts
#   MC sample 100 , loss = 195.35079899514068
#   MC sample 200 , loss = 195.35900489726802
#   MC sample 300 , loss = 195.3507798573881
#   MC sample 400 , loss = 195.32881808208467
#   MC sample 500 , loss = 195.32661367904518
#   MC sample 600 , loss = 195.33032095455243
#   MC sample 700 , loss = 195.3136503404212
#   MC sample 800 , loss = 195.3202094190409
#   MC sample 900 , loss = 195.31995609853584
#   Time shifts sampling = 9.330970048904419
#   mean(a_shifts) = 0.002663191499455143
# Sampling the volume
#   Iter 100 , a =  0.0
#   MC sample 100 , loss (of mean) = 195.08265995265828
#   Time volume sampling = 29.651515007019043
#   mean(a_vol) = 0.7133343663229915
# 2022-03-18 17:36:41.695270
#   nx = 16
# Iter  17
# Sampling orientations
#   MC sample 100 , loss = 251.74748843129743
#   MC sample 200 , loss = 251.71265704829517
#   MC sample 300 , loss = 251.69041185179898
#   MC sample 400 , loss = 251.65857869867074
#   MC sample 500 , loss = 251.63983558997643
#   MC sample 600 , loss = 251.62716987532747
#   MC sample 700 , loss = 251.59472439050438
#   MC sample 800 , loss = 251.59487346813586
#   MC sample 900 , loss = 251.58864443270156
#   Time orientations sampling = 21.372274160385132
#   mean(a_angles) = 0.0007800862803155411
# Sampling shifts
#   MC sample 100 , loss = 251.57342549275572
#   MC sample 200 , loss = 251.5817105215918
#   MC sample 300 , loss = 251.55263620966633
#   MC sample 400 , loss = 251.5438718622628
#   MC sample 500 , loss = 251.5442505972567
#   MC sample 600 , loss = 251.53726673797723
#   MC sample 700 , loss = 251.52993284453743
#   MC sample 800 , loss = 251.5212986073302
#   MC sample 900 , loss = 251.52227179947226
#   Time shifts sampling = 11.627517461776733
#   mean(a_shifts) = 0.0025846061923598448
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 251.1356721698095
#   Time volume sampling = 35.47440028190613
#   mean(a_vol) = 0.7002734326903126
# Iter  18
# Sampling orientations
#   MC sample 100 , loss = 251.66844281891042
#   MC sample 200 , loss = 251.628795342688
#   MC sample 300 , loss = 251.61522460179032
#   MC sample 400 , loss = 251.5847788549402
#   MC sample 500 , loss = 251.55838022853612
#   MC sample 600 , loss = 251.53111981482488
#   MC sample 700 , loss = 251.51185859690935
#   MC sample 800 , loss = 251.48016768107266
#   MC sample 900 , loss = 251.4590610210446
#   Time orientations sampling = 21.464558124542236
#   mean(a_angles) = 0.0006940663915607179
# Sampling shifts
#   MC sample 100 , loss = 251.4105513344056
#   MC sample 200 , loss = 251.3985373778836
#   MC sample 300 , loss = 251.38350236745276
#   MC sample 400 , loss = 251.37796611506982
#   MC sample 500 , loss = 251.37659418432705
#   MC sample 600 , loss = 251.36658911915012
#   MC sample 700 , loss = 251.34942329232973
#   MC sample 800 , loss = 251.35384386187337
#   MC sample 900 , loss = 251.34426912787873
#   Time shifts sampling = 9.681177616119385
#   mean(a_shifts) = 0.0025477647316679694
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 250.99882209612775
#   Time volume sampling = 35.11111760139465
#   mean(a_vol) = 0.7611903272391258
# Iter  19
# Sampling orientations
#   MC sample 100 , loss = 251.50708189223187
#   MC sample 200 , loss = 251.48460092509623
#   MC sample 300 , loss = 251.4611556915688
#   MC sample 400 , loss = 251.43051832904888
#   MC sample 500 , loss = 251.41135005788544
#   MC sample 600 , loss = 251.3792786707515
#   MC sample 700 , loss = 251.35204848151656
#   MC sample 800 , loss = 251.33758352668622
#   MC sample 900 , loss = 251.31961440423552
#   Time orientations sampling = 21.391901969909668
#   mean(a_angles) = 0.0006592696747409893
# Sampling shifts
#   MC sample 100 , loss = 251.2956724745323
#   MC sample 200 , loss = 251.28481322152723
#   MC sample 300 , loss = 251.27125357178508
#   MC sample 400 , loss = 251.2622364163695
#   MC sample 500 , loss = 251.26481311563973
#   MC sample 600 , loss = 251.26147128310018
#   MC sample 700 , loss = 251.26057269409185
#   MC sample 800 , loss = 251.26261841115803
#   MC sample 900 , loss = 251.26192498028345
#   Time shifts sampling = 11.628066301345825
#   mean(a_shifts) = 0.002539759699245659
# Sampling the volume
#   Iter 100 , a =  0.947872498076719
#   MC sample 100 , loss (of mean) = 250.82514107374365
#   Time volume sampling = 35.07036113739014
#   mean(a_vol) = 0.7299428219313596
# Iter  20
# Sampling orientations
#   MC sample 100 , loss = 251.40465620454546
#   MC sample 200 , loss = 251.37745473899014
#   MC sample 300 , loss = 251.36542765684493
#   MC sample 400 , loss = 251.3420971929754
#   MC sample 500 , loss = 251.3245725273965
#   MC sample 600 , loss = 251.29096294952092
#   MC sample 700 , loss = 251.2968363131432
#   MC sample 800 , loss = 251.27290022408974
#   MC sample 900 , loss = 251.26186276718244
#   Time orientations sampling = 21.340308904647827
#   mean(a_angles) = 0.0006278031747405314
# Sampling shifts
#   MC sample 100 , loss = 251.20726212594724
#   MC sample 200 , loss = 251.19310826318014
#   MC sample 300 , loss = 251.1899472022976
#   MC sample 400 , loss = 251.17721245149906
#   MC sample 500 , loss = 251.19330721942612
#   MC sample 600 , loss = 251.18350395458975
#   MC sample 700 , loss = 251.18445466577998
#   MC sample 800 , loss = 251.1915163906739
#   MC sample 900 , loss = 251.20493822952687
#   Time shifts sampling = 9.700410604476929
#   mean(a_shifts) = 0.00248896542996184
# Sampling the volume
#   Iter 100 , a =  0.0
#   MC sample 100 , loss (of mean) = 250.76098210876464
#   Time volume sampling = 35.46830487251282
#   mean(a_vol) = 0.7701546344526723
# Iter  21
# Sampling orientations
#   MC sample 100 , loss = 307.58717676197256
#   MC sample 200 , loss = 307.5625835551421
#   MC sample 300 , loss = 307.54930989826306
#   MC sample 400 , loss = 307.5283034808607
#   MC sample 500 , loss = 307.5066897209269
#   MC sample 600 , loss = 307.49254967122135
#   MC sample 700 , loss = 307.4675405834161
#   MC sample 800 , loss = 307.4495159445381
#   MC sample 900 , loss = 307.4339050802529
#   Time orientations sampling = 24.207542896270752
#   mean(a_angles) = 0.000603956305234313
# Sampling shifts
#   MC sample 100 , loss = 307.3861372548944
#   MC sample 200 , loss = 307.3856227090494
#   MC sample 300 , loss = 307.3587801771018
#   MC sample 400 , loss = 307.3440407090613
#   MC sample 500 , loss = 307.3548571116822
#   MC sample 600 , loss = 307.3511420727451
#   MC sample 700 , loss = 307.3467464931955
#   MC sample 800 , loss = 307.3341813433151
#   MC sample 900 , loss = 307.33443343648696
#   Time shifts sampling = 12.558557987213135
#   mean(a_shifts) = 0.002483796516087542
# Sampling the volume
#   Iter 100 , a =  0.0
#   MC sample 100 , loss (of mean) = 306.89741959414073
#   Time volume sampling = 42.93141484260559
#   mean(a_vol) = 0.7383399631509825
# Iter  22
# Sampling orientations
#   MC sample 100 , loss = 307.62626437022044
#   MC sample 200 , loss = 307.6163451910441
#   MC sample 300 , loss = 307.5780655512601
#   MC sample 400 , loss = 307.5546565204534
#   MC sample 500 , loss = 307.5318099766618
#   MC sample 600 , loss = 307.5090396235785
#   MC sample 700 , loss = 307.4844416819863
#   MC sample 800 , loss = 307.4524229923495
#   MC sample 900 , loss = 307.42230758874996
#   Time orientations sampling = 23.730281591415405
#   mean(a_angles) = 0.0005816354471750747
# Sampling shifts
#   MC sample 100 , loss = 307.3699898847725
#   MC sample 200 , loss = 307.36294988826904
#   MC sample 300 , loss = 307.35612485032334
#   MC sample 400 , loss = 307.3538381781456
#   MC sample 500 , loss = 307.34092626953327
#   MC sample 600 , loss = 307.33412296196195
#   MC sample 700 , loss = 307.3331986170686
#   MC sample 800 , loss = 307.3293492714528
#   MC sample 900 , loss = 307.3124273017521
#   Time shifts sampling = 10.275437116622925
#   mean(a_shifts) = 0.0024204768311741755
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 306.6575528810244
#   Time volume sampling = 40.11541771888733
#   mean(a_vol) = 0.7398324341836287
# Iter  23
# Sampling orientations
#   MC sample 100 , loss = 307.4011673059876
#   MC sample 200 , loss = 307.3696638565781
#   MC sample 300 , loss = 307.35189351051815
#   MC sample 400 , loss = 307.3289464489292
#   MC sample 500 , loss = 307.3058595412248
#   MC sample 600 , loss = 307.3067868013855
#   MC sample 700 , loss = 307.3021235368305
#   MC sample 800 , loss = 307.29094612489297
#   MC sample 900 , loss = 307.2804229186687
#   Time orientations sampling = 23.77536129951477
#   mean(a_angles) = 0.0005048246060225985
# Sampling shifts
#   MC sample 100 , loss = 307.2396157728854
#   MC sample 200 , loss = 307.21382878721215
#   MC sample 300 , loss = 307.2093835578915
#   MC sample 400 , loss = 307.2138264044678
#   MC sample 500 , loss = 307.2108172171777
#   MC sample 600 , loss = 307.1959647526581
#   MC sample 700 , loss = 307.1805175825485
#   MC sample 800 , loss = 307.1873914971342
#   MC sample 900 , loss = 307.1907418135457
#   Time shifts sampling = 10.218969345092773
#   mean(a_shifts) = 0.0023689600259909145
# Sampling the volume
#   Iter 100 , a =  0.979457809266195
#   MC sample 100 , loss (of mean) = 306.60165919174983
#   Time volume sampling = 40.09306764602661
#   mean(a_vol) = 0.799095867952367
# Iter  24
# Sampling orientations
#   MC sample 100 , loss = 307.3150849078356
#   MC sample 200 , loss = 307.2809466937247
#   MC sample 300 , loss = 307.26424455330493
#   MC sample 400 , loss = 307.24958901991465
#   MC sample 500 , loss = 307.2271894925875
#   MC sample 600 , loss = 307.2108315639683
#   MC sample 700 , loss = 307.1981361408625
#   MC sample 800 , loss = 307.1691824373558
#   MC sample 900 , loss = 307.1565693371336
#   Time orientations sampling = 23.7396297454834
#   mean(a_angles) = 0.0005203253469052408
# Sampling shifts
#   MC sample 100 , loss = 307.13406966620744
#   MC sample 200 , loss = 307.11654549626365
#   MC sample 300 , loss = 307.10960742893263
#   MC sample 400 , loss = 307.08459321972686
#   MC sample 500 , loss = 307.07697482121506
#   MC sample 600 , loss = 307.07745704326476
#   MC sample 700 , loss = 307.0826247007753
#   MC sample 800 , loss = 307.0787128759644
#   MC sample 900 , loss = 307.0825719881417
#   Time shifts sampling = 10.134207487106323
#   mean(a_shifts) = 0.0023628974665936787
# Sampling the volume
#   Iter 100 , a =  0.0
#   MC sample 100 , loss (of mean) = 306.4407937819006
#   Time volume sampling = 40.127281188964844
#   mean(a_vol) = 0.6995023288022428
# 2022-03-18 17:46:38.970222
#   nx = 20
# Iter  25
# Sampling orientations
#   MC sample 100 , loss = 375.6836674402749
#   MC sample 200 , loss = 375.6676645180966
#   MC sample 300 , loss = 375.64064110865513
#   MC sample 400 , loss = 375.61399606609456
#   MC sample 500 , loss = 375.5933707626922
#   MC sample 600 , loss = 375.57070661705256
#   MC sample 700 , loss = 375.556931480432
#   MC sample 800 , loss = 375.54715274905925
#   MC sample 900 , loss = 375.5311824429279
#   Time orientations sampling = 27.431968450546265
#   mean(a_angles) = 0.0005027201310503749
# Sampling shifts
#   MC sample 100 , loss = 375.5040525002951
#   MC sample 200 , loss = 375.493126101012
#   MC sample 300 , loss = 375.4722997321774
#   MC sample 400 , loss = 375.467981949783
#   MC sample 500 , loss = 375.46480520503525
#   MC sample 600 , loss = 375.45969594006914
#   MC sample 700 , loss = 375.45854514075387
#   MC sample 800 , loss = 375.4479096687787
#   MC sample 900 , loss = 375.44819600960915
#   Time shifts sampling = 13.194854974746704
#   mean(a_shifts) = 0.0023701082639887216
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 374.70699644475917
#   Time volume sampling = 49.62767696380615
#   mean(a_vol) = 0.7139833708250742
# Iter  26
# Sampling orientations
#   MC sample 100 , loss = 375.7319592012074
#   MC sample 200 , loss = 375.69649548416743
#   MC sample 300 , loss = 375.6795442420739
#   MC sample 400 , loss = 375.6615173637674
#   MC sample 500 , loss = 375.6462017847164
#   MC sample 600 , loss = 375.6131024867617
#   MC sample 700 , loss = 375.59236940291464
#   MC sample 800 , loss = 375.56970761665247
#   MC sample 900 , loss = 375.53681391142374
#   Time orientations sampling = 27.234521627426147
#   mean(a_angles) = 0.0004626310691765337
# Sampling shifts
#   MC sample 100 , loss = 375.4915024267727
#   MC sample 200 , loss = 375.4744151657249
#   MC sample 300 , loss = 375.4580169293068
#   MC sample 400 , loss = 375.4273122505326
#   MC sample 500 , loss = 375.415021513353
#   MC sample 600 , loss = 375.4104605670026
#   MC sample 700 , loss = 375.40801968477746
#   MC sample 800 , loss = 375.4104526888469
#   MC sample 900 , loss = 375.4145530356818
#   Time shifts sampling = 10.971349000930786
#   mean(a_shifts) = 0.0022751361642318626
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 374.4756878316213
#   Time volume sampling = 46.56122303009033
#   mean(a_vol) = 0.7263471281398117
# Iter  27
# Sampling orientations
#   MC sample 100 , loss = 375.55789047310185
#   MC sample 200 , loss = 375.529682911503
#   MC sample 300 , loss = 375.5004896064061
#   MC sample 400 , loss = 375.47950884318334
#   MC sample 500 , loss = 375.45967710086114
#   MC sample 600 , loss = 375.444121823839
#   MC sample 700 , loss = 375.41759287684096
#   MC sample 800 , loss = 375.4008805271189
#   MC sample 900 , loss = 375.38228967304724
#   Time orientations sampling = 29.197139978408813
#   mean(a_angles) = 0.0004315087195975069
# Sampling shifts
#   MC sample 100 , loss = 375.3385557865377
#   MC sample 200 , loss = 375.31084410166824
#   MC sample 300 , loss = 375.2828953056835
#   MC sample 400 , loss = 375.28046575366386
#   MC sample 500 , loss = 375.2740961482467
#   MC sample 600 , loss = 375.25695434721763
#   MC sample 700 , loss = 375.25201142850796
#   MC sample 800 , loss = 375.25436769603465
#   MC sample 900 , loss = 375.2596745621834
#   Time shifts sampling = 10.832205057144165
#   mean(a_shifts) = 0.0022250489739215535
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 374.40876089807136
#   Time volume sampling = 46.493175745010376
#   mean(a_vol) = 0.6880076697872872
# Iter  28
# Sampling orientations
#   MC sample 100 , loss = 375.45362697971893
#   MC sample 200 , loss = 375.42823434154286
#   MC sample 300 , loss = 375.39475127879876
#   MC sample 400 , loss = 375.37793848451406
#   MC sample 500 , loss = 375.3518862089732
#   MC sample 600 , loss = 375.3206812913891
#   MC sample 700 , loss = 375.2994216298359
#   MC sample 800 , loss = 375.28459785353203
#   MC sample 900 , loss = 375.2630817231697
#   Time orientations sampling = 27.07011914253235
#   mean(a_angles) = 0.0004039777150813178
# Sampling shifts
#   MC sample 100 , loss = 375.23620153815995
#   MC sample 200 , loss = 375.2050216621484
#   MC sample 300 , loss = 375.20474382422555
#   MC sample 400 , loss = 375.1950805826784
#   MC sample 500 , loss = 375.178711500556
#   MC sample 600 , loss = 375.1751479235954
#   MC sample 700 , loss = 375.18206015892036
#   MC sample 800 , loss = 375.1778378941025
#   MC sample 900 , loss = 375.1709358737908
#   Time shifts sampling = 11.058736324310303
#   mean(a_shifts) = 0.0022218817533951377
# Sampling the volume
#   Iter 100 , a =  0.9890132001995454
#   MC sample 100 , loss (of mean) = 374.2503078167082
#   Time volume sampling = 46.73613786697388
#   mean(a_vol) = 0.7672139398627791
# Iter  29
# Sampling orientations
#   MC sample 100 , loss = 439.7619964272962
#   MC sample 200 , loss = 439.7329799842045
#   MC sample 300 , loss = 439.71062107153296
#   MC sample 400 , loss = 439.68509467676375
#   MC sample 500 , loss = 439.66580035711405
#   MC sample 600 , loss = 439.64236705788267
#   MC sample 700 , loss = 439.6252808726985
#   MC sample 800 , loss = 439.60662328435876
#   MC sample 900 , loss = 439.59525058355183
#   Time orientations sampling = 31.565781116485596
#   mean(a_angles) = 0.0003894999122338924
# Sampling shifts
#   MC sample 100 , loss = 439.55427019037813
#   MC sample 200 , loss = 439.5304688504864
#   MC sample 300 , loss = 439.5333927829914
#   MC sample 400 , loss = 439.53346077764604
#   MC sample 500 , loss = 439.5292005670304
#   MC sample 600 , loss = 439.5159625305921
#   MC sample 700 , loss = 439.5100028621668
#   MC sample 800 , loss = 439.49565415485614
#   MC sample 900 , loss = 439.48447745256186
#   Time shifts sampling = 10.704018831253052
#   mean(a_shifts) = 0.002211419629437089
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 438.374407485984
#   Time volume sampling = 53.949830770492554
#   mean(a_vol) = 0.7512383770007887
# Iter  30
# Sampling orientations
#   MC sample 100 , loss = 439.8029752439916
#   MC sample 200 , loss = 439.78364525858603
#   MC sample 300 , loss = 439.75347367118104
#   MC sample 400 , loss = 439.734661731134
#   MC sample 500 , loss = 439.7074840470126
#   MC sample 600 , loss = 439.68539286840604
#   MC sample 700 , loss = 439.66906526086314
#   MC sample 800 , loss = 439.64963117504476
#   MC sample 900 , loss = 439.62694990136515
#   Time orientations sampling = 28.84130859375
#   mean(a_angles) = 0.00033840729484768515
# Sampling shifts
#   MC sample 100 , loss = 439.5902782629956
#   MC sample 200 , loss = 439.5479162601721
#   MC sample 300 , loss = 439.5232181942465
#   MC sample 400 , loss = 439.5212408957991
#   MC sample 500 , loss = 439.50109229859396
#   MC sample 600 , loss = 439.4932937887291
#   MC sample 700 , loss = 439.4767767108927
#   MC sample 800 , loss = 439.4758717829121
#   MC sample 900 , loss = 439.4683521131253
#   Time shifts sampling = 10.427254676818848
#   mean(a_shifts) = 0.0021402089955777034
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 438.2725882725469
#   Time volume sampling = 51.03603982925415
#   mean(a_vol) = 0.7646725589326121
# Iter  31
# Sampling orientations
#   MC sample 100 , loss = 439.6489956218254
#   MC sample 200 , loss = 439.6244197738439
#   MC sample 300 , loss = 439.59472647450923
#   MC sample 400 , loss = 439.576607235117
#   MC sample 500 , loss = 439.55843146338606
#   MC sample 600 , loss = 439.5430318836776
#   MC sample 700 , loss = 439.5148132655454
#   MC sample 800 , loss = 439.501569967928
#   MC sample 900 , loss = 439.48700694709015
#   Time orientations sampling = 28.977740049362183
#   mean(a_angles) = 0.0003180206714548382
# Sampling shifts
#   MC sample 100 , loss = 439.4272978145963
#   MC sample 200 , loss = 439.4214426516123
#   MC sample 300 , loss = 439.4105563217209
#   MC sample 400 , loss = 439.4058807660485
#   MC sample 500 , loss = 439.3957113434922
#   MC sample 600 , loss = 439.3849099179052
#   MC sample 700 , loss = 439.3807464551261
#   MC sample 800 , loss = 439.3849102868806
#   MC sample 900 , loss = 439.3696211181296
#   Time shifts sampling = 10.121092081069946
#   mean(a_shifts) = 0.0020836046494984565
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 438.19701198655963
#   Time volume sampling = 51.183528900146484
#   mean(a_vol) = 0.762869416878554
# Iter  32
# Sampling orientations
#   MC sample 100 , loss = 439.59791616110834
#   MC sample 200 , loss = 439.5795223794474
#   MC sample 300 , loss = 439.55381894036293
#   MC sample 400 , loss = 439.53691027939414
#   MC sample 500 , loss = 439.52685211852514
#   MC sample 600 , loss = 439.5074444480281
#   MC sample 700 , loss = 439.49566090164865
#   MC sample 800 , loss = 439.47271126579125
#   MC sample 900 , loss = 439.46398501213156
#   Time orientations sampling = 28.9227454662323
#   mean(a_angles) = 0.0003132275225719483
# Sampling shifts
#   MC sample 100 , loss = 439.41136369561315
#   MC sample 200 , loss = 439.40025446104653
#   MC sample 300 , loss = 439.38326819818553
#   MC sample 400 , loss = 439.37085247609303
#   MC sample 500 , loss = 439.35482108430847
#   MC sample 600 , loss = 439.3468334432565
#   MC sample 700 , loss = 439.33036714571625
#   MC sample 800 , loss = 439.3264823622294
#   MC sample 900 , loss = 439.3247379824146
#   Time shifts sampling = 10.328187704086304
#   mean(a_shifts) = 0.0020713333133050237
# Sampling the volume
#   Iter 100 , a =  0.9199674786933283
#   MC sample 100 , loss (of mean) = 438.0812589958752
#   Time volume sampling = 50.92504262924194
#   mean(a_vol) = 0.6955438766142661
# 2022-03-18 17:59:14.696829
#   nx = 24
# Iter  33
# Sampling orientations
#   MC sample 100 , loss = 527.8365272527058
#   MC sample 200 , loss = 527.8215291009499
#   MC sample 300 , loss = 527.8008889639266
#   MC sample 400 , loss = 527.7826136908471
#   MC sample 500 , loss = 527.7708934240137
#   MC sample 600 , loss = 527.7456576779892
#   MC sample 700 , loss = 527.7226379376464
#   MC sample 800 , loss = 527.7120043273133
#   MC sample 900 , loss = 527.6972078816724
#   Time orientations sampling = 36.87180829048157
#   mean(a_angles) = 0.00030002878601071987
# Sampling shifts
#   MC sample 100 , loss = 527.6558485119508
#   MC sample 200 , loss = 527.6259065536689
#   MC sample 300 , loss = 527.6187626904996
#   MC sample 400 , loss = 527.6132474604017
#   MC sample 500 , loss = 527.6004850072258
#   MC sample 600 , loss = 527.5876753005041
#   MC sample 700 , loss = 527.5822885796196
#   MC sample 800 , loss = 527.5966238554307
#   MC sample 900 , loss = 527.5898725551139
#   Time shifts sampling = 14.535862445831299
#   mean(a_shifts) = 0.002054567408333794
# Sampling the volume
#   Iter 100 , a =  0.9808939342465794
#   MC sample 100 , loss (of mean) = 526.4016116259271
#   Time volume sampling = 68.02362847328186
#   mean(a_vol) = 0.8052756802614152
# Iter  34
# Sampling orientations
#   MC sample 100 , loss = 528.0167311374177
#   MC sample 200 , loss = 527.9918975735873
#   MC sample 300 , loss = 527.96595592463
#   MC sample 400 , loss = 527.9570685114339
#   MC sample 500 , loss = 527.9261570786978
#   MC sample 600 , loss = 527.9107347338515
#   MC sample 700 , loss = 527.8907342611939
#   MC sample 800 , loss = 527.8738305589358
#   MC sample 900 , loss = 527.8556271543596
#   Time orientations sampling = 36.784316539764404
#   mean(a_angles) = 0.0002699013700686354
# Sampling shifts
#   MC sample 100 , loss = 527.8011594016018
#   MC sample 200 , loss = 527.7729381917774
#   MC sample 300 , loss = 527.7329228824664
#   MC sample 400 , loss = 527.7295707897921
#   MC sample 500 , loss = 527.7179034101333
#   MC sample 600 , loss = 527.7009572201887
#   MC sample 700 , loss = 527.6897390815856
#   MC sample 800 , loss = 527.6847443967991
#   MC sample 900 , loss = 527.6600663535027
#   Time shifts sampling = 11.933125495910645
#   mean(a_shifts) = 0.0019460888166825724
# Sampling the volume
#   Iter 100 , a =  0.9508070486623793
#   MC sample 100 , loss (of mean) = 526.1441346437998
#   Time volume sampling = 65.04890036582947
#   mean(a_vol) = 0.749418121211982
# Iter  35
# Sampling orientations
#   MC sample 100 , loss = 527.8719910651781
#   MC sample 200 , loss = 527.8576764414499
#   MC sample 300 , loss = 527.8244492413617
#   MC sample 400 , loss = 527.8015667411653
#   MC sample 500 , loss = 527.7862532851948
#   MC sample 600 , loss = 527.7654510040427
#   MC sample 700 , loss = 527.749446215161
#   MC sample 800 , loss = 527.738179395406
#   MC sample 900 , loss = 527.73142733832
#   Time orientations sampling = 36.66134071350098
#   mean(a_angles) = 0.0002557129400859596
# Sampling shifts
#   MC sample 100 , loss = 527.6868017386363
#   MC sample 200 , loss = 527.6647081923551
#   MC sample 300 , loss = 527.6473314482464
#   MC sample 400 , loss = 527.6311203749005
#   MC sample 500 , loss = 527.607879858083
#   MC sample 600 , loss = 527.5866882548682
#   MC sample 700 , loss = 527.590151322298
#   MC sample 800 , loss = 527.6014193813978
#   MC sample 900 , loss = 527.5972768599873
#   Time shifts sampling = 14.158763408660889
#   mean(a_shifts) = 0.0018886963522997172
# Sampling the volume
#   Iter 100 , a =  0.9507018006096011
#   MC sample 100 , loss (of mean) = 526.1674643814166
#   Time volume sampling = 65.06914067268372
#   mean(a_vol) = 0.8084051602594877
# Iter  36
# Sampling orientations
#   MC sample 100 , loss = 527.8113948635095
#   MC sample 200 , loss = 527.7874606603422
#   MC sample 300 , loss = 527.7691751268394
#   MC sample 400 , loss = 527.7479255005449
#   MC sample 500 , loss = 527.7292376895716
#   MC sample 600 , loss = 527.7183501931413
#   MC sample 700 , loss = 527.6976391047097
#   MC sample 800 , loss = 527.6749961245948
#   MC sample 900 , loss = 527.6523923966768
#   Time orientations sampling = 36.593411445617676
#   mean(a_angles) = 0.00024715714340218137
# Sampling shifts
#   MC sample 100 , loss = 527.6009590785752
#   MC sample 200 , loss = 527.5716287911023
#   MC sample 300 , loss = 527.5521847501601
#   MC sample 400 , loss = 527.5559050663973
#   MC sample 500 , loss = 527.5307658967007
#   MC sample 600 , loss = 527.5295170698024
#   MC sample 700 , loss = 527.5144952336675
#   MC sample 800 , loss = 527.5032437260007
#   MC sample 900 , loss = 527.494731552549
#   Time shifts sampling = 12.046119928359985
#   mean(a_shifts) = 0.001877679744366322
# Sampling the volume
#   Iter 100 , a =  0.9278692020398087
#   MC sample 100 , loss (of mean) = 525.9919205048718
#   Time volume sampling = 65.10391521453857
#   mean(a_vol) = 0.6791058390825717
# Iter  37
# Sampling orientations
#   MC sample 100 , loss = 615.9994392830873
#   MC sample 200 , loss = 615.9850819185821
#   MC sample 300 , loss = 615.9695408097864
#   MC sample 400 , loss = 615.9458878012259
#   MC sample 500 , loss = 615.9273766051869
#   MC sample 600 , loss = 615.9139190327006
#   MC sample 700 , loss = 615.9026881247449
#   MC sample 800 , loss = 615.8931630426825
#   MC sample 900 , loss = 615.8746955338197
#   Time orientations sampling = 41.367960691452026
#   mean(a_angles) = 0.00023517084603064397
# Sampling shifts
#   MC sample 100 , loss = 615.8396834771094
#   MC sample 200 , loss = 615.8018484262798
#   MC sample 300 , loss = 615.7834787390932
#   MC sample 400 , loss = 615.7676569309472
#   MC sample 500 , loss = 615.7470511459409
#   MC sample 600 , loss = 615.7497507553293
#   MC sample 700 , loss = 615.7458030854466
#   MC sample 800 , loss = 615.741123525079
#   MC sample 900 , loss = 615.7354754567777
#   Time shifts sampling = 16.326444387435913
#   mean(a_shifts) = 0.0018588757011617683
# Sampling the volume
#   Iter 100 , a =  1.0
#   MC sample 100 , loss (of mean) = 614.3572599848496
#   Time volume sampling = 76.3728940486908
#   mean(a_vol) = 0.8091516923173662
# Iter  38
# Sampling orientations
#   MC sample 100 , loss = 616.2124354159223
#   MC sample 200 , loss = 616.1973338644335
#   MC sample 300 , loss = 616.1781517627338
#   MC sample 400 , loss = 616.1671604951358
#   MC sample 500 , loss = 616.1439589612896
#   MC sample 600 , loss = 616.123486646023
#   MC sample 700 , loss = 616.1020761360537
#   MC sample 800 , loss = 616.0886307667051
#   MC sample 900 , loss = 616.0745666249363
#   Time orientations sampling = 41.07278656959534
#   mean(a_angles) = 0.00021496386213206792
# Sampling shifts
#   MC sample 100 , loss = 616.0331239227137
#   MC sample 200 , loss = 616.0159577585131
#   MC sample 300 , loss = 615.9823169268408
#   MC sample 400 , loss = 615.9572277370576
#   MC sample 500 , loss = 615.9344680463521
#   MC sample 600 , loss = 615.912771523278
#   MC sample 700 , loss = 615.9137450568177
#   MC sample 800 , loss = 615.8989453665882
#   MC sample 900 , loss = 615.9018133629698
#   Time shifts sampling = 13.795550346374512
#   mean(a_shifts) = 0.0017676587399766011
# Sampling the volume
# 2022-03-18 18:10:59.366613: E external/org_tensorflow/tensorflow/compiler/xla/pjrt/pjrt_stream_executor_client.cc:2140] Execution of replica 0 failed: INTERNAL: Failed to load in-memory CUBIN: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [46], in <module>
#      43 imgs = imgs.reshape([N, nx*nx])
#      44 #v_rec, angles_rec = ab_initio(project, imgs, sigma_noise, shifts_true, ctf_params, x_grid, use_sgd, N_iter, N_vol_iter, learning_rate, batch_size, P, N_samples, radius, dr, alpha, eps_vol, 'tri', True, True, True, out_dir)
# ---> 45 v_rec, angles_rec, shifts_rec = ab_initio_mcmc(key,
#      46                                    project,
#      47                                    rotate_and_interpolate,
#      48                                    apply_shifts_and_ctf,
#      49                                    imgs,
#      50                                    sigma_noise,
#      51                                    ctf_params,
#      52                                    x_grid,
#      53                                    use_sgd,
#      54                                    vol0,
#      55                                    angles0,
#      56                                    shifts0,
#      57                                    N_iter,
#      58                                    learning_rate,
#      59                                    batch_size,
#      60                                    P,
#      61                                    N_samples_vol,
#      62                                    N_samples_angles,
#      63                                    N_samples_shifts,
#      64                                    dt_list,
#      65                                    L,
#      66                                    radius,
#      67                                    dr,
#      68                                    alpha,
#      69                                    eps_vol,
#      70                                    B,
#      71                                    'tri',
#      72                                    True, True, True, out_dir)
#
# File /gpfs/loomis/project/lederman/bt387/simple_cryoem/src/ab_initio.py:394, in ab_initio_mcmc(key, project_func, rotate_and_interpolate_func, apply_shifts_and_ctf_func, imgs, sigma_noise, ctf_params, x_grid, use_sgd, vol0, angles0, shifts0, N_iter, learning_rate, batch_size, P, N_samples_vol, N_samples_angles, N_samples_shifts, dt_list, L, radius0, dr, alpha, eps_vol, B, interp_method, opt_vol_first, verbose, save_to_file, out_dir)
#     390 @jax.jit
#     391 def proposal_hmc_jit(key, x0):
#     392     return proposal_hmc(key, x0, logPi_vol, gradLogPi_vol, jnp.array(dt_list), L, M_iter)
# --> 394 v_hmc_mean, r_hmc, v_hmc_samples = mcmc(subkey, proposal_hmc_jit, v, N_samples_vol, logPi_vol, save_samples = 1)
#     395 #v = v_hmc_mean
#     396 v = v_hmc_samples[N_samples_vol-2]
#
# File /gpfs/loomis/project/lederman/bt387/simple_cryoem/src/algorithm.py:349, in mcmc(key, proposal_func, x0, N_samples, logPi, N_batch, save_samples, verbose)
#     345 for i in range(1, N_samples):
#     346     #t0 = time.time()
#     348     x0 = x1
# --> 349     x1, r = proposal_func(keys[2*i], x0)
#     350     a = jnp.minimum(1, r)
#     351     r_samples.append(a)
#
#     [... skipping hidden 6 frame]
#
# File /gpfs/loomis/project/lederman/bt387/conda_envs/j_lab/lib/python3.10/site-packages/jax/_src/dispatch.py:444, in _execute_compiled(name, compiled, output_buffer_counts, result_handlers, kept_var_idx, *args)
#     441 device, = compiled.local_devices()
#     442 input_bufs = util.flatten(
#     443     device_put(x, device) for i, x in enumerate(args) if i in kept_var_idx)
# --> 444 out_bufs = compiled.execute(input_bufs)
#     445 check_special(name, out_bufs)
#     446 if output_buffer_counts is None:
#
# RuntimeError: INTERNAL: Failed to load in-memory CUBIN: CUDA_ERROR_OUT_OF_MEMORY: out of memory

# %%
plt.imshow(jnp.real(jnp.fft.fftshift(jnp.fft.ifftn(v_rec[:,:,0])))); plt.colorbar()

# %%
plt.imshow(jnp.abs(jnp.fft.fftshift(v_rec[:,:,0]))); plt.colorbar()

# %%
plot_angles(angles_rec[:1000])

# %%
shifts_err = wrap_arround_distance_2d_array(shifts_true, shifts_rec, 10)
print("mean shift error =", jnp.mean(shifts_err), "in [", -10, ",", 10, "]^2")
plt.plot(shifts_err)

# %%
plot_angles(angles_true[:1000])

# %% [markdown]
# ## Optimization with respect to volume

# %% [markdown]
# ### CG - applied to two halves of the data

# %%
v0 = jnp.array(np.random.randn(nx,nx,nx) + 1j * np.random.randn(nx,nx,nx))
N_iter = 600
eps_cg = 1e-5

N2 = jnp.floor(N/2).astype(jnp.int64)
#N2 = 100000
AA1, Ab1 = get_cg_vol_ops(grad_loss_volume_sum, angles_true[:N2], shifts_true[:N2], ctf_params[:N2], imgs[:N2], v0.shape)

vcg1,_ = conjugate_gradient(AA1, Ab1, v0, N_iter, eps_cg, verbose = True)
# Out:
#   cg iter 0 ||r|| = 64.0999131168545
#   cg iter 50 ||r|| = 0.00022445505923135778
#   cg iter 100 ||r|| = 9.904533574292494e-05
#   cg iter 150 ||r|| = 5.536797285466404e-05
#   cg iter 200 ||r|| = 3.191014759157713e-05
#   cg iter 250 ||r|| = 2.6158492823062747e-05
#   cg iter 300 ||r|| = 2.5489091313994322e-05
#   cg iter 350 ||r|| = 2.5521880315329098e-05
#   cg iter 400 ||r|| = 2.2327517957044257e-05
#   cg iter 450 ||r|| = 1.8715437013090208e-05
#   cg iter 500 ||r|| = 1.5610226409670588e-05
#   cg iter 550 ||r|| = 1.5686219118109472e-05

# %%
AA2, Ab2 = get_cg_vol_ops(grad_loss_volume_sum, angles_true[N2:], shifts_true[N2:], ctf_params[N2:], imgs[N2:], v0.shape)

vcg2, _ = conjugate_gradient(AA2, Ab2, v0, N_iter, eps_cg, verbose = True)
# Out:
#   cg iter 0 ||r|| = 73.69929948438595
#   cg iter 50 ||r|| = 0.00016700125237854795
#   cg iter 100 ||r|| = 5.8671104429629774e-05
#   cg iter 150 ||r|| = 3.586747732177588e-05
#   cg iter 200 ||r|| = 3.0431897624318876e-05
#   cg iter 250 ||r|| = 2.370623291835185e-05
#   cg iter 300 ||r|| = 2.339111653712353e-05
#   cg iter 350 ||r|| = 2.5356056414641797e-05
#   cg iter 400 ||r|| = 2.201810842703514e-05
#   cg iter 450 ||r|| = 2.1754316144376644e-05
#   cg iter 500 ||r|| = 1.778383940300002e-05
#   cg iter 550 ||r|| = 1.6398462698863898e-05

# %%
#print("Final loss function = ", loss_func_sum(vcg, angles_true, shifts_true, ctf_params, imgs))
print("Relative error = ", jnp.max(jnp.abs((vcg1 - vol_fourier)/jnp.max(vol_fourier))))
print("Absolute error = ", jnp.mean(jnp.abs((vcg1 - vol_fourier))))
# Out:
# Relative error =  0.4922433392098166
# Absolute error =  3.662052789934649

# %%
#mip_z(jnp.abs(jnp.fft.fftshift((vcg1)))) ; 
plt.imshow(jnp.abs(jnp.fft.fftshift((vcg1[0,:,:])))) ; 
plt.colorbar()

# %%
idx = 709

s0 = slice_func(vcg1, angles_true[idx], shifts_true[idx], ctf_params[idx])
plt.imshow(jnp.fft.fftshift(jnp.real(s0).reshape(nx,nx))); plt.colorbar()

# %%
#mip_y(jnp.real(jnp.fft.fftshift(jnp.fft.ifftn(vcg1))))
plt.imshow(jnp.real(jnp.fft.fftshift(jnp.fft.ifftn(vcg1[:,:,0]))))
plt.colorbar()
#plt.title('Reconstruction slice')

# %%
#mip_z(jnp.real(jnp.fft.fftshift(jnp.fft.ifftn(vcg2))))
plt.imshow(jnp.real(jnp.fft.fftshift(jnp.fft.ifftn(v_rec[0,:,:]))))
plt.colorbar()
plt.title('Reconstruction MIP')
# Out:
# Text(0.5, 1.0, 'Reconstruction MIP')

# %%
mip_z(jnp.abs(jnp.fft.fftshift((vcg1-vol_fourier)/jnp.max(vol_fourier))));plt.colorbar()

plt.title("Reconstruction relative error (Fourier)")
# Out:
# Text(0.5, 1.0, 'Reconstruction relative error (Fourier)')

# %%
mip_z(jnp.abs(jnp.fft.fftshift(jnp.fft.ifftn((vol_fourier - vcg1)))))
plt.colorbar()
plt.title('Error in spatial domain with low freq vol - MIP')
# Out:
# Text(0.5, 1.0, 'Error in spatial domain with low freq vol - MIP')

# %%
vr = jnp.real(jnp.fft.fftshift(jnp.fft.ifftn(v_hmc_mean)))

with mrcfile.new('../data/simulated_rec_vhmc.mrc', overwrite=True) as mrc:
    mrc.set_data(vr.astype(np.float32))

# %%
vr = jnp.real(jnp.fft.fftshift(jnp.fft.ifftn(vol_fourier)))

with mrcfile.new('../data/simulated_vol_16.mrc', overwrite=True) as mrc:
    mrc.set_data(vr.astype(np.float32))

# %% [markdown]
# ### FSC

# %%
res, fsc, shell_points = calc_fsc(vcg1, v_hmc_max, x_grid, dr = 0.05)

# %%
points_v_tri = points_orientations_tri(angles_true[:int(N/2)], int(x_grid[1]))
#points_v_nn = points_orientations_nn(angles_true, x_grid[1])
# Out:
# Rotating coordinates
# Finding point indices
# Splitting in batches.
# Adding up number of points from batches.

# %%
#points_v_nn = points_orientations_nn(angles_true, x_grid[1])

# %%
res_spu, spu_tri = shell_points_used(points_v_tri, x_grid, dr = 0.05)

# %%
plt.plot(res, fsc)
plt.plot(res_spu, spu_tri)
plt.hlines([0.143, 0.5], xmin=min(res), xmax=max(res), colors = ['gray'], linestyles=['dashed'])
plt.legend(['FSC', 'fraction shell points used', '0.143, 0.5'])
#plt.title('Clustered angles')

# %%
plt.imshow(jnp.fft.fftshift((points_v_tri[0,:,:]*mask[0,:,:]))); plt.colorbar()

# %%
#res_spu, spu_nn = shell_points_used(points_v_nn, x_grid, dr = 0.05)
#plt.plot(res_spu, spu_nn)

# %% [markdown]
# ### James

# %% [markdown]
# The mean is given by CG as applied above, in addition we need to calculate the variances.
# The variances are given by the inverse of the gradient (AA) applied to diag(1), i.e. a volume with ones.
#
# Looks good and agrees with counting the points above, but for whatever reason it's mirrored compared to above hmmm.

# %%
vones = jnp.ones(vcg1.shape)
omega = AA1(vones)
omega = 1/omega

# %%
plt.title("Standard deviation")
plt.imshow((jnp.sqrt(jnp.abs(jnp.fft.fftshift(omega[0,:,:]))))); plt.colorbar()

# %%
plt.title("Mean")
plt.imshow((jnp.abs(jnp.fft.fftshift(vcg1[:,:,0])))); plt.colorbar()

# %% [markdown]
# ### SGD

# %% [markdown]
# #### A preconditioner

# %%
points_v_nn.shape
P = points_v_nn
P += 0.1
P = 1/P  * mask

P = P/jnp.max(P)

plt.imshow(jnp.fft.fftshift(P[:,:,0]));plt.colorbar()
print(P[0,0,0])
print(jnp.max(P))
# Out:
# 0.011098890110988899
# 1.0

# %%
v0 = jnp.array(np.random.randn(nx,nx,nx) + 1j * np.random.randn(nx,nx,nx))
batch_size = N/2
N_epoch = 100
eps_gd = 1e-3
learning_rate = 1
#alpha = 100000 # <- with normalized precon

sgd_grad_func = get_sgd_vol_ops(grad_loss_volume_batched, angles_true, shifts_true, ctf_params, imgs)
vgd = sgd(sgd_grad_func, N, v0, learning_rate, N_epoch, batch_size, None, eps_gd, True)

print("Final loss function (over all data) = ", jnp.mean(loss_func_batched(vgd, angles_true, shifts_true, ctf_params, imgs, 1)))
print("Relative error = ", jnp.max(jnp.abs((vgd - vol_fourier)/jnp.max(vol_fourier))))
# Out:
#   sgd epoch 0: mean gradient = 0.042522726770200386
#   sgd epoch 10: mean gradient = 0.0030659381781304672
#   sgd epoch 20: mean gradient = 0.0016716639562312395
#   sgd epoch 30: mean gradient = 0.0007006905204310624
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/t3/hcx4r4_961g84bb7t1m8hjqc0000gn/T/ipykernel_1464/417236957.py in <module>
#       9 vgd = sgd(sgd_grad_func, N, v0, learning_rate, N_epoch, batch_size, None, eps_gd, True)
#      10
# ---> 11 print("Final loss function (over all data) = ", jnp.mean(loss_func_batched(vgd, angles_true, shifts_true, ctf_params, imgs)))
#      12 print("Relative error = ", jnp.max(jnp.abs((vgd - vol_fourier)/jnp.max(vol_fourier))))
#
#     [... skipping hidden 13 frame]
#
# /opt/anaconda3/lib/python3.9/site-packages/jax/linear_util.py in call_wrapped(self, *args, **kwargs)
#     164
#     165     try:
# --> 166       ans = self.f(*args, **dict(self.params, **kwargs))
#     167     except:
#     168       # Some transformations yield from inside context managers, so we have to
#
# TypeError: loss_func_batched() missing 1 required positional argument: 'sigma'

# %%
mip_z(jnp.abs(jnp.fft.fftshift((vgd*mask-vol_fourier*mask)/jnp.max(vol_fourier))));plt.colorbar()

plt.title("Reconstruction relative error (Fourier)")
# Out:
# Text(0.5, 1.0, 'Reconstruction relative error (Fourier)')

# %%
plt.imshow(jnp.real(jnp.fft.fftshift(jnp.fft.ifftn(vgd[:,:,0]*mask[:,:,0]))))
plt.colorbar()
plt.title('Reconstruction MIP')
# Out:
# Text(0.5, 1.0, 'Reconstruction MIP')

# %%
mip_z(jnp.abs(jnp.fft.fftshift((vgd)))) ; plt.colorbar()

# %%
mip_z(jnp.abs(jnp.fft.fftshift(jnp.fft.ifftn((vol_fourier*mask - vgd*mask)))))
plt.colorbar()
plt.title('Error in spatial domain with low freq vol - MIP')
# Out:
# Text(0.5, 1.0, 'Error in spatial domain with low freq vol - MIP')

# %% [markdown]
# And the error with the high freq volume

# %%
mip_z(jnp.abs(jnp.real(jnp.fft.fftshift(jnp.fft.ifftn(vol_fourier - vgd)))))
plt.colorbar()
plt.title('Reconstruction error with high freq vol -  MIP')
# Out:
# Text(0.5, 1.0, 'Reconstruction error with high freq vol -  MIP')

# %%
mip_z(jnp.abs(jnp.real(jnp.fft.fftshift(jnp.fft.ifftn(vol_fourier - vol_fourier*mask)))))
plt.colorbar()
plt.title('Reconstruction error with high freq vol -  MIP')
# Out:
# Text(0.5, 1.0, 'Reconstruction error with high freq vol -  MIP')

# %% [markdown]
# ### Volume residual

# %%
#alpha = 1e-10
alpha = 1e-5

radius_mask = 0.75
mask = create_3d_mask(x_grid, (0,0,0), radius_mask)
#mip_z(jnp.fft.fftshift(mask)); plt.colorbar()

slice_func,slice_func_array, slice_func_array_angles = get_slice_funcs(project, x_grid, mask, "tri")
loss_func, loss_func_batched, loss_func_sum, _ = get_loss_funcs(slice_func, alpha = alpha)
grad_loss_volume, grad_loss_volume_sum = get_grad_v_funcs(loss_func, loss_func_sum)

# %%
v0 = jnp.array(np.random.randn(nx,nx,nx) + 1j * np.random.randn(nx,nx,nx))
N_iter = 5000
eps_cg = 1e-5

N_train = jnp.floor(N/2).astype(jnp.int64)
AA, Ab = get_cg_vol_ops(grad_loss_volume_sum, angles_true[:N_train], shifts_true[:N_train], ctf_params[:N_train], imgs[:N_train], v0.shape, sigma_noise)

v_train,_ = conjugate_gradient(AA, Ab, v0, N_iter, eps_cg, verbose = True)
# Out:
#   cg iter 0 ||r|| = 0.0438027382447892
#   cg iter 50 ||r|| = 4.8303001359695344e-05
#   cg iter 100 ||r|| = 2.7372043812015585e-05
#   cg iter 150 ||r|| = 1.8385717922028983e-05
#   cg iter 200 ||r|| = 2.2919685492922857e-05
#   cg iter 250 ||r|| = 1.7078214447343223e-05
#   cg iter 300 ||r|| = 1.8150638896641013e-05
#   cg iter 350 ||r|| = 1.47488064208539e-05
#   cg iter 400 ||r|| = 1.4620664405688343e-05
#   cg iter 414 ||r|| = 9.963732327016209e-06

# %%
plot_true_vs_estimated(vol_fourier, v_train)

# %% [markdown]
# #### Create the volume

# %% [markdown]
# Set enough batches so that each batch fits in the GPU memory.
# Also, more batches is better as one big batch takes ages to compile on
# the GPU.
# The initial compilation takes quite a while, then it's fast.
# At some point it slows down, probably to recompile (likely
# for the one batch that has a different size, although I don't
# know why that happens at about 33% and not at the end).

# %%
N_batches = 60000

v_resid = get_volume_residual(v_train, angles_true[N_train:], shifts_true[N_train:], ctf_params[N_train:], imgs[N_train:], x_grid, slice_func_array, N_batches)

plt.imshow(jnp.fft.fftshift(v_resid[:,:,0])); plt.colorbar()
# Out:
# 100%|██████████| 60000/60000 [01:19<00:00, 756.50it/s]

# %%
plt.imshow(jnp.fft.fftshift(v_resid[:,:,0]*mask[:,:,0])); plt.colorbar()

# %%
v_resid_print = jnp.fft.fftshift(v_resid*mask)

with mrcfile.new('../data/resid_vol.mrc', overwrite=True) as mrc:
    mrc.set_data(v_resid_print.astype(np.float32))
